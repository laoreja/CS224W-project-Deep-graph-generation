# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import networkx as nx

# %%
from utils.data_helper import create_graphs

# %%
grid_graphs = create_graphs('grid', data_dir='data')
# Out:
# max # nodes = 361 || mean # nodes = 210.25
# max # edges = 684 || mean # edges = 391.5

# %%
for g in grid_graphs:
    print(g.graph['i_nodes'], g.graph['j_nodes'])

# %%
dd_graphs = create_graphs('DD', data_dir='data')
# Out:
# Loading graph dataset: DD
# label_cnt {1: 582, 2: 336}
# Loaded
# max # nodes = 500 || mean # nodes = 257.86710239651416
# max # edges = 1575 || mean # edges = 646.4226579520697

# %%
print(len(dd_graphs))
# Out:
# 918

# %%
import random
sampled_graphs = random.sample(subset_graphs, 10)

# %%
from collections import defaultdict
for G in dd_graphs[:10]:
    node_degree_list = [(n, d) for n, d in G.degree()]
    num_core = nx.core_number(G)
    core_order_list = sorted(list(set(num_core.values())), reverse=True)
    degree_dict = dict(G.degree())
    core_to_node = defaultdict(list)
    for nn, kk in num_core.items():
        core_to_node[kk] += [nn]

    node_list = []
    for kk in core_order_list:
        sort_node_tuple = sorted(
          [(nn, degree_dict[nn]) for nn in core_to_node[kk]],
          key=lambda tt: tt[1],
          reverse=True)
        node_list += [nn for nn, dd in sort_node_tuple]

    adj_5 = np.array(nx.to_numpy_matrix(G, nodelist=node_list))
    
    plt.figure()
    plt.matshow(adj_5)
    plt.show()

# %%
import random
fig, axes = plt.subplots(1, 4, figsize=(15,15))
for i in range(4):
    G = random.choice(dd_graphs)
#     G = dd_graphs[i]
    node_degree_list = [(n, d) for n, d in G.degree()]
    num_core = nx.core_number(G)
    core_order_list = sorted(list(set(num_core.values())), reverse=True)
    degree_dict = dict(G.degree())
    core_to_node = defaultdict(list)
    for nn, kk in num_core.items():
        core_to_node[kk] += [nn]

    node_list = []
    for kk in core_order_list:
        sort_node_tuple = sorted(
          [(nn, degree_dict[nn]) for nn in core_to_node[kk]],
          key=lambda tt: tt[1],
          reverse=True)
        node_list += [nn for nn, dd in sort_node_tuple]

    adj_5 = np.array(nx.to_numpy_matrix(G, nodelist=node_list))
    
    axes[i].set_axis_off()
    axes[i].matshow(adj_5)
plt.savefig('../final_report/protein_adj_matricies.png', bbox_inches = 'tight', dpi=600)

# %%
for G in dd_graphs[-10:]:
    node_degree_list = [(n, d) for n, d in G.degree()]
    num_core = nx.core_number(G)
    core_order_list = sorted(list(set(num_core.values())), reverse=True)
    degree_dict = dict(G.degree())
    core_to_node = defaultdict(list)
    for nn, kk in num_core.items():
        core_to_node[kk] += [nn]

    node_list = []
    for kk in core_order_list:
        sort_node_tuple = sorted(
          [(nn, degree_dict[nn]) for nn in core_to_node[kk]],
          key=lambda tt: tt[1],
          reverse=True)
        node_list += [nn for nn, dd in sort_node_tuple]

    adj_5 = np.array(nx.to_numpy_matrix(G, nodelist=node_list))
    
    plt.figure()
    plt.matshow(adj_5)
    plt.show()
